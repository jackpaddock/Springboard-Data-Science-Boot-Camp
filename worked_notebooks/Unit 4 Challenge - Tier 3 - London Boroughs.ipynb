# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_London = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
#properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)
properties = pd.read_excel(url_London, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.shape
# Out:
# (339, 49)

# %%
#Display first five rows of my dataframe
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
#Transpose variable to flip x,y
properties_T= properties.transpose()
print(properties_T.shape)
# Out:
# (49, 339)

# %%
#Display first five rows of my dataframe... after my variable has been transposed
properties_T.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
#Display index of transposed index
properties_T.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
#Reset index of transposed variable since I do not want the boroughs to be my index
properties_T = properties_T.reset_index()

#Display updated index information
properties_T.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %%
#Display first five rows of transposed variable after its index has been reset
##Columns headers and index are almost identical it seems... the first row aka row[0] should be the column headers
properties_T.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
#                      6                    7                    8  ...  \
# ...

# %%
#Now that I have looked the index. Lets check out the columns. Call .columns to confirm that headers are integers based on output preview above
##Looks good so far but the ellipsis could be hiding an improper value
properties_T.columns

#Display the first row and make it reflect the date values ala the headers are the date values. This looks great.
properties_T.iloc[[0]]
# Out:
#         index    0                    1                    2  \
# 0  Unnamed: 0  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
#
#                    329                  330                  331  \
# 0  2022-05-01 00:00:00  2022-06-01 00:00:00  2022-07-01 00:00:00
#
#                    332                  333                  334  \
# 0  2022-08-01 00:00:00  2022-09-01 00:00:00  2022-10-01 00:00:00
#
#                    335                  336                  337  \
# 0  2022-11-01 00:00:00  2022-12-01 00:00:00  2023-01-01 00:00:00
#
#                    338
# 0  2023-02-01 00:00:00
#
# [1 rows x 340 columns]

# %%
#Assign updated headers to .columns to lock in column headers
properties_T.columns = properties_T.iloc[0]

#Display first five rows of transposed, updated variable. This looks better... row[0] does not look correct. It is not needed.
properties_T.head()
# Out:
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
#Remove row[0] from dataframe as it is not needed
properties_T = properties_T.drop(0)
properties_T
# Out:
# 0             Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1         City of London  E09000001         91448.98487         82202.77314
# 2     Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3                 Barnet  E09000003         93284.51832         93190.16963
# 4                 Bexley  E09000004         64958.09036         64787.92069
# 5                  Brent  E09000005         71306.56698         72022.26197
# 6                Bromley  E09000006         81671.47692         81657.55944
# 7                 Camden  E09000007         120932.8881         119508.8622
# 8                Croydon  E09000008         69158.16225         68951.09542
# 9                 Ealing  E09000009         79885.89069         80897.06551
# 10               Enfield  E09000010         72514.69096         73155.19746
# 11             Greenwich  E09000011         62300.10169         60993.26863
# ...

# %% [markdown]
# I have some NaNs, Boroughs indexes with names "Unnamed," and column headers "Unnamed:0" + "NaT." These will need to be cleaned up!

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
#Rename column headers. ASK Thierno about pd.NaT. It took me some time to figure out I had to apply pandas to it.
properties_T = properties_T.rename(columns = {'Unnamed: 0':'London_Borough', pd.NaT: 'ID'})
properties_T.head()
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
#The .melt() function will reshape the properties_T dataframe as it will unpivot it from wide format to long format
properties_M = pd.melt(properties_T, id_vars = ['London_Borough', 'ID'])

print(properties_M.shape)

#Looks good but I will need to rename two column headers once again.
properties_M.head()
# Out:
# (16224, 4)
#        London_Borough         ID          0        value
# 0      City of London  E09000001 1995-01-01  91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01   50460.2266
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698

# %%
#Rename column headers to better articulate dataframe
properties_M = properties_M.rename(columns = {0: 'Month', 'value': 'Average_Price'})

#Looks great! This is as intended so far.
properties_M.head()
# Out:
#        London_Borough         ID      Month Average_Price
# 0      City of London  E09000001 1995-01-01   91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.2266
# 2              Barnet  E09000003 1995-01-01   93284.51832
# 3              Bexley  E09000004 1995-01-01   64958.09036
# 4               Brent  E09000005 1995-01-01   71306.56698

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
#Check data types
properties_M.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_Price             object
# dtype: object

# %%
#Convert average_price's data type of object to float data type
properties_M['Average_Price'] = pd.to_numeric(properties_M['Average_Price'])

#Check data types again
properties_M.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_Price            float64
# dtype: object

# %%
#Count # of values per column. The column values do not tie out...
properties_M.count()
# Out:
# London_Borough    16224
# ID                15210
# Month             16224
# Average_Price     15210
# dtype: int64

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
#Check out London_Borough column to see if any null values exist. So far so good but I need to keep digging to confirm. 
properties_M['London_Borough'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16219    False
# 16220    False
# 16221    False
# 16222    False
# 16223    False
# Name: London_Borough, Length: 16224, dtype: bool

# %%
#Check out London_Borough column to see if any incorrect values are stored. There are a few unnamed Borough values amd then locations in capitalized letters that do not fit.
properties_M['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
#Dig into Borough values that appear to be useless. Columns "ID" and "Average_Price" have NaNs.
properties_M[properties_M['London_Borough'] == 'Unnamed: 34'].head()
# Out:
#     London_Borough   ID      Month  Average_Price
# 33     Unnamed: 34  NaN 1995-01-01            NaN
# 81     Unnamed: 34  NaN 1995-02-01            NaN
# 129    Unnamed: 34  NaN 1995-03-01            NaN
# 177    Unnamed: 34  NaN 1995-04-01            NaN
# 225    Unnamed: 34  NaN 1995-05-01            NaN

# %%
#Dig into Borough values that appear to be useless
properties_M[properties_M['London_Borough'] == 'LONDON'].head()
# Out:
#     London_Borough         ID      Month  Average_Price
# 43          LONDON  E12000007 1995-01-01    74435.76052
# 91          LONDON  E12000007 1995-02-01    72777.93709
# 139         LONDON  E12000007 1995-03-01    73896.84204
# 187         LONDON  E12000007 1995-04-01    74455.28754
# 235         LONDON  E12000007 1995-05-01    75432.02786

# %%
#Drop NaNs from dataframe
properties_NaNFree = properties_M.dropna()

# %%
#NaNs successfully dropped for columns "ID" and "Average_Price' which means the "Unnamed..." Borough values are removed.
properties_NaNFree['Average_Price'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16218    False
# 16219    False
# 16220    False
# 16221    False
# 16223    False
# Name: Average_Price, Length: 15210, dtype: bool

# %%
properties_NaNFree[properties_NaNFree['London_Borough'] == 'Unnamed: 34'].head()
# Out:
# Empty DataFrame
# Columns: [London_Borough, ID, Month, Average_Price]
# Index: []

# %%
#Check # of column values after cleanup work. Success!
properties_NaNFree.count()
# Out:
# London_Borough    15210
# ID                15210
# Month             15210
# Average_Price     15210
# dtype: int64

# %%
#Currect x,y of dataframe after adjustments
print(properties_NaNFree.shape)
# Out:
# (15210, 4)

# %%
#Now that the "Unnamed..." Borough values are removed. I need to address the location values in the London_Borough column.
nonBoroughs = ['Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England']

#Remove other Borough values that are not relevant (stored in nonBoroughs).
properties_NaNFree = properties_NaNFree[~properties_NaNFree.London_Borough.isin(nonBoroughs)]
properties_NaNFree
# Out:
#            London_Borough         ID      Month  Average_Price
# 0          City of London  E09000001 1995-01-01    91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                  Barnet  E09000003 1995-01-01    93284.51832
# 3                  Bexley  E09000004 1995-01-01    64958.09036
# 4                   Brent  E09000005 1995-01-01    71306.56698
# ...                   ...        ...        ...            ...
# 16204              Sutton  E09000029 2023-02-01   447798.81270
# 16205       Tower Hamlets  E09000030 2023-02-01   502932.34100
# 16206      Waltham Forest  E09000031 2023-02-01   509781.86160
# 16207          Wandsworth  E09000032 2023-02-01   639194.17770
# 16208         Westminster  E09000033 2023-02-01   968017.39860
#
# [11154 rows x 4 columns]

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
#Pullback Westminster Borough's Average Pricing
westminster_price = properties_NaNFree[properties_NaNFree['London_Borough'] == 'Westminster']

#Plot Westminster Borough's Average Pricing. Y-Axis needs a label!
plot = westminster_price.plot(kind='line', x='Month', y='Average_Price', title='Westminster Average Price per Month')

#Give Y-Axis a name, Price
plot.set_ylabel('Price (M) in GBP')
# Out:
# Text(0, 0.5, 'Price (M) in GBP')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
#Add new column called 'Year' to dataframe using the column 'Month.'
properties_NaNFree['Year'] = properties_NaNFree['Month'].dt.year
#properties_NaNFree['Year'] = properties_NaNFree['Month'].apply(lambda y: y.year)
properties_NaNFree
# Out:
#            London_Borough         ID      Month  Average_Price  Year
# 0          City of London  E09000001 1995-01-01    91448.98487  1995
# 1      Barking & Dagenham  E09000002 1995-01-01    50460.22660  1995
# 2                  Barnet  E09000003 1995-01-01    93284.51832  1995
# 3                  Bexley  E09000004 1995-01-01    64958.09036  1995
# 4                   Brent  E09000005 1995-01-01    71306.56698  1995
# ...                   ...        ...        ...            ...   ...
# 16204              Sutton  E09000029 2023-02-01   447798.81270  2023
# 16205       Tower Hamlets  E09000030 2023-02-01   502932.34100  2023
# 16206      Waltham Forest  E09000031 2023-02-01   509781.86160  2023
# 16207          Wandsworth  E09000032 2023-02-01   639194.17770  2023
# 16208         Westminster  E09000033 2023-02-01   968017.39860  2023
#
# [11154 rows x 5 columns]

# %%
#Pullback London Borough pricing for last two decades by year. Index needs to reset again.
dfg = properties_NaNFree.groupby(by=['London_Borough', 'Year']).mean()
dfg
# Out:
#                          Average_Price
# London_Borough     Year
# Barking & Dagenham 1995   51817.969390
#                    1996   51718.192690
#                    1997   55974.262309
#                    1998   60285.821083
#                    1999   65320.934441
# ...                                ...
# Westminster        2019  955998.608925
#                    2020  960469.218567
#                    2021  962777.447967
#                    2022  999703.468367
#                    2023  962494.345150
#
# [957 rows x 1 columns]

# %%
#Correct index orientation
dfg = dfg.reset_index()
dfg
# Out:
#          London_Borough  Year  Average_Price
# 0    Barking & Dagenham  1995   51817.969390
# 1    Barking & Dagenham  1996   51718.192690
# 2    Barking & Dagenham  1997   55974.262309
# 3    Barking & Dagenham  1998   60285.821083
# 4    Barking & Dagenham  1999   65320.934441
# ..                  ...   ...            ...
# 952         Westminster  2019  955998.608925
# 953         Westminster  2020  960469.218567
# 954         Westminster  2021  962777.447967
# 955         Westminster  2022  999703.468367
# 956         Westminster  2023  962494.345150
#
# [957 rows x 3 columns]

# %%
dfg.loc[dfg['Average_Price'].idxmax()]
# Out:
# London_Borough    Kensington & Chelsea
# Year                              2022
# Average_Price           1436877.959908
# Name: 578, dtype: object

# %%
dfg[dfg['Average_Price'] == dfg['Average_Price'].max()]
# Out:
#            London_Borough  Year  Average_Price
# 578  Kensington & Chelsea  2022   1.436878e+06

# %%
dfg.dtypes
# Out:
# London_Borough     object
# Year                int64
# Average_Price     float64
# dtype: object

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
#Write function based on above instruction. Keep in mind data types.
def create_price_ratio(x):
    y1998 = float(x['Average_Price'][x['Year'] == 1998])
    y2018 = float(x['Average_Price'][x['Year'] == 2018])
    ratio = [y1998/y2018]
    return ratio

#Call function with Westminster Borough as filter
create_price_ratio(dfg[dfg['London_Borough'] == 'Westminster'])
# Out:
# [0.1867914047302468]

# %%
#Loop through all values in London_Borough column.
all_boroughs = {}

for i in set(dfg['London_Borough']):
    london_borough = dfg[dfg['London_Borough'] == i]
    all_boroughs[i] = create_price_ratio(london_borough)
    
#See results of price ratio per London_Borough via all_borough dictionary
all_boroughs
# Out:
# {'Brent': [0.2043086864360114],
#  'Croydon': [0.23803288028014052],
#  'Hammersmith & Fulham': [0.24167443054605847],
#  'Lambeth': [0.20170435486140825],
#  'Kingston upon Thames': [0.2341619023428255],
#  'Westminster': [0.1867914047302468],
#  'Tower Hamlets': [0.21613672276235532],
#  'Hounslow': [0.25148317824115635],
#  'Kensington & Chelsea': [0.19675491852791563],
#  'Redbridge': [0.2236545053715767],
#  'Barnet': [0.229452741207858],
#  'Greenwich': [0.20995010893854213],
#  'Hillingdon': [0.23807975835429931],
#  'Barking & Dagenham': [0.20422256235393685],
#  'Camden': [0.20261973503252542],
#  'Islington': [0.20643891170300288],
#  'Wandsworth': [0.21018518091593216],
#  'Harrow': [0.24635417785626296],
#  'Bromley': [0.24421308489837315],
#  'City of London': [0.18862157770244364],
#  'Sutton': [0.24280551426824518],
#  'Haringey': [0.19475619095546956],
#  'Lewisham': [0.18351246764721704],
#  'Southwark': [0.18127484171283456],
# ...

# %%
#Convert dictionary all_boroughs into a dataframe. It will provide better reporting capabilities to solve business case.
borough_ratios = pd.DataFrame(all_boroughs)
borough_ratios
# Out:
#       Brent   Croydon  Hammersmith & Fulham   Lambeth  Kingston upon Thames  \
# 0  0.204309  0.238033              0.241674  0.201704              0.234162
#
#    Westminster  Tower Hamlets  Hounslow  Kensington & Chelsea  Redbridge  ...  \
# 0     0.186791       0.216137  0.251483              0.196755   0.223655  ...
#
#    Southwark  Waltham Forest    Bexley  Havering   Hackney    Merton  \
# 0   0.181275        0.171387  0.235351  0.231202  0.161335  0.210914
#
#    Richmond upon Thames   Enfield    Newham   Ealing
# 0              0.249678  0.234551  0.188488  0.23194
#
# [1 rows x 33 columns]

# %%
#Transpose dataframe and output it
borough_ratios_T = borough_ratios.transpose()
print(borough_ratios_T.sort_values(0))
# Out:
#                              0
# Hackney               0.161335
# Waltham Forest        0.171387
# Southwark             0.181275
# Lewisham              0.183512
# Westminster           0.186791
# Newham                0.188488
# City of London        0.188622
# Haringey              0.194756
# Kensington & Chelsea  0.196755
# Lambeth               0.201704
# Camden                0.202620
# Barking & Dagenham    0.204223
# Brent                 0.204309
# Islington             0.206439
# Greenwich             0.209950
# Wandsworth            0.210185
# Merton                0.210914
# Tower Hamlets         0.216137
# Redbridge             0.223655
# Barnet                0.229453
# Havering              0.231202
# Ealing                0.231940
# Kingston upon Thames  0.234162
# Enfield               0.234551
# Bexley                0.235351
# Croydon               0.238033
# Hillingdon            0.238080
# Hammersmith & Fulham  0.241674
# Sutton                0.242806
# ...

# %%
#reset index to rename column headers
borough_ratios_T = borough_ratios_T.reset_index()
borough_ratios_T
# Out:
#                    index         0
# 0                  Brent  0.204309
# 1                Croydon  0.238033
# 2   Hammersmith & Fulham  0.241674
# 3                Lambeth  0.201704
# 4   Kingston upon Thames  0.234162
# 5            Westminster  0.186791
# 6          Tower Hamlets  0.216137
# 7               Hounslow  0.251483
# 8   Kensington & Chelsea  0.196755
# 9              Redbridge  0.223655
# 10                Barnet  0.229453
# 11             Greenwich  0.209950
# 12            Hillingdon  0.238080
# 13    Barking & Dagenham  0.204223
# 14                Camden  0.202620
# 15             Islington  0.206439
# 16            Wandsworth  0.210185
# 17                Harrow  0.246354
# 18               Bromley  0.244213
# 19        City of London  0.188622
# 20                Sutton  0.242806
# 21              Haringey  0.194756
# 22              Lewisham  0.183512
# 23             Southwark  0.181275
# 24        Waltham Forest  0.171387
# 25                Bexley  0.235351
# ...

# %%
#Rename column headers to better articulate dataframe
borough_ratios_T = borough_ratios_T.rename(columns = {'index': 'London_Borough', 0: '2018 Price Ratio'})
borough_ratios_T.sort_values(by = '2018 Price Ratio', ascending = False)
# Out:
#           London_Borough  2018 Price Ratio
# 7               Hounslow          0.251483
# 29  Richmond upon Thames          0.249678
# 17                Harrow          0.246354
# 18               Bromley          0.244213
# 20                Sutton          0.242806
# 2   Hammersmith & Fulham          0.241674
# 12            Hillingdon          0.238080
# 1                Croydon          0.238033
# 25                Bexley          0.235351
# 30               Enfield          0.234551
# 4   Kingston upon Thames          0.234162
# 32                Ealing          0.231940
# 26              Havering          0.231202
# 10                Barnet          0.229453
# 9              Redbridge          0.223655
# 6          Tower Hamlets          0.216137
# 28                Merton          0.210914
# 16            Wandsworth          0.210185
# 11             Greenwich          0.209950
# 15             Islington          0.206439
# 0                  Brent          0.204309
# ...

# %%
#Plot dataframe via bar chart
plot2 = borough_ratios_T.plot(kind = 'bar', x = 'London_Borough', y = '2018 Price Ratio', title = 'London Borough 2018 Price Ratio Comparison' )

#Give Y-Axis a name, Price
plot2.set_ylabel('Price Ratio in GBP')
plot2.set_ylim([0, 0.30])
# Out:
# (0.0, 0.3)

# %%
top10_boroughs = borough_ratios_T.sort_values(by = '2018 Price Ratio', ascending = False).head(10)
print(top10_boroughs)

plot_top10_boroughs = top10_boroughs.plot(kind = 'bar', x = 'London_Borough', y = '2018 Price Ratio', title = '2018 Top 10 Highest London Borough Price Ratio Increases')
plot_top10_boroughs.set_ylim([0, 0.30])
# Out:
#           London_Borough  2018 Price Ratio
# 7               Hounslow          0.251483
# 29  Richmond upon Thames          0.249678
# 17                Harrow          0.246354
# 18               Bromley          0.244213
# 20                Sutton          0.242806
# 2   Hammersmith & Fulham          0.241674
# 12            Hillingdon          0.238080
# 1                Croydon          0.238033
# 25                Bexley          0.235351
# 30               Enfield          0.234551
# (0.0, 0.3)

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# In the period from 1998 to 2018, the data relfects the highest increase in housing are displayed above (Top 10 London Borough Bar chart). The borough Hounslow had the highest increase coming in at 0.251483 followed by Richmond upon Thames with 0.249678.
