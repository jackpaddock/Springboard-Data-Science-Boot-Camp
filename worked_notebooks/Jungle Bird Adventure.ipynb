# %%
#task2 create bird dictionary
rarebirds = {
    'Gold-Crested Toucan': {
        'Height (m)': 1.1,
        'Weight (kg)': 35,
        'Color': 'Gold',
        'Endangered': True,
        'Aggressive': True},
    
'Pearlescent Kingfisher': {
        'Height (m)': 0.25,
        'Weight (kg)': 0.5,
        'Color': 'White',
        'Endangered': False,
        'Aggressive': False},

'Four-Metre Hummingbird': {
        'Height (m)': 0.6,
        'Weight (kg)': 0.5,
        'Color': 'Blue',
        'Endangered': True,
        'Aggressive': False},
    
'Giant Eagle': {
        'Height (m)': 1.5,
        'Weight (kg)': 53,
        'Color': 'Black and White',
        'Endangered': True,
        'Aggressive': True},
    
'Ancient Vulture': {
        'Height (m)': 2.1,
        'Weight (kg)': 70,
        'Color': 'Brown',
        'Endangered': False,
        'Aggressive': False}
 }

#task2 create birdlocation dictionary
birdlocation = ['In the canopy directly above our heads.',
                'Between my 6 and 9 o’clock above.',
                'Between my 9 and 12 o’clock above.',
                'Between my 12 and 3 o’clock above.',
                'Between my 3 and 6 o’clock above.'
                'In a nest on the ground.',
                'Right behind you.']

#task3 create binary code, bird location dictionary
codes = {'111': 'In the canopy directly above our heads.',
         '110': 'Between my 6 and 9 o’clock above.',
         '101': 'Between my 9 and 12 o’clock above.',
         '100': 'Between my 12 and 3 o’clock above.',
         '011': 'Between my 3 and 6 o’clock above.',
         '010': 'In a nest on the ground.',
         '001': 'Right behind you.'}

#task4 create list of actions
actions = ['Back Away', 'Cover our Heads', 'Take a Photograph']

#task 6 description of what to do depending on the bird we come across
print("Here's how to handle the birds: ")
for key, value, in rarebirds.items():
    if value['Aggressive'] == True & value['Endangered'] == True: 
        print(key + ": " + actions[1] + " & " + actions[0])
    elif value['Aggressive'] == True: 
        print(key + ": " + actions[1])
    elif value['Endangered'] == True: 
        print(key + ": " + actions[0])
    else:
        print(key + ": " + actions[2])
print()
        
#task 7 print binary code dictionary
print("Bird Locations:")
for key, value in codes.items():
    print(key + ": " + value)
print()

#task8 add an extra bird attribute to rarebirds dictionary called "seen" 
for value in rarebirds.values():
    value['Seen'] = False

#task9 make new encounter variable
encounter = True

#task10 take user input
sighting = input("Hi! What do you see? ").title()

#task11 make a list of rarebirdslist
rarebirdsList = list(rarebirds.keys())
print(rarebirdsList)

#task12 check if sighting is on rare bird list
if sighting in rarebirdsList:
    print("This is one of the birds we're looking for. ")
else: 
    print("That is not one of the birds we're looking for.")

#Task 13
code = input('Where do you see it? Input the correct code.')

#Task 14
location = codes[code]

#Task 15
print("So you've seen a", sighting, location, "My goodness.")

#Task 16
if rarebirds[sighting.title()]['Aggressive'] == True:
    print('That bird is aggressive. We need to ' + actions[0] + ' and ' + actions[1])
    print('We need to ' + actions[2] + ' ' + location)
elif rarebirds[sighting.title()]['Endangered'] == True:
    print('That bird is endangered. We need to ' + actions[0])
    print('We need to ' + actions[2] + ' ' + location)
else:
    print('That ' + sighting + ' is ultra rare! We need to ' + actions[2] + ' ' + location)
# Out:
# Here's how to handle the birds:
# Gold-Crested Toucan: Cover our Heads & Back Away
# Pearlescent Kingfisher: Take a Photograph
# Four-Metre Hummingbird: Back Away
# Giant Eagle: Cover our Heads & Back Away
# Ancient Vulture: Take a Photograph
#
# Bird Locations:
# 111: In the canopy directly above our heads.
# 110: Between my 6 and 9 o’clock above.
# 101: Between my 9 and 12 o’clock above.
# 100: Between my 12 and 3 o’clock above.
# 011: Between my 3 and 6 o’clock above.
# 010: In a nest on the ground.
# 001: Right behind you.
#
# Hi! What do you see? Four-Metre Hummingbird
# ['Gold-Crested Toucan', 'Pearlescent Kingfisher', 'Four-Metre Hummingbird', 'Giant Eagle', 'Ancient Vulture']
# This is one of the birds we're looking for.
# Where do you see it? Input the correct code.001
# So you've seen a Four-Metre Hummingbird Right behind you. My goodness.
# That bird is endangered. We need to Back Away
# We need to Take a Photograph Right behind you.
